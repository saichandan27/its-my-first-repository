# %% [markdown]
# <a href="https://colab.research.google.com/github/saichandan27/its-my-first-repository/blob/main/SE_LAB_TASK_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 123
rev = 0
while num > 0:
    rev = rev * 10 + num % 10
    num //= 10
print(rev)
# Out:
# 321

# %%
num = -5
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Negative

# %%
a = 8
b = 4
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: 12
# Subtraction: 4
# Multiplication: 32
# Division: 2.0

# %%
year = 2024
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Leap Year

# %%
n = 5
fact = 1
for i in range(1, n + 1):
    fact *= i
print(fact)
# Out:
# 120

# %%
num = 121
temp = num
rev = 0

while num > 0:
    rev = rev * 10 + num % 10
    num //= 10

if temp == rev:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Palindrome

# %%
n = 10
total = 0
for i in range(1, n + 1):
    total += i
print(total)
# Out:
# 55
